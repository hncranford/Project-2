# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect


engine = create_engine("postgresql://postgres:postgres@localhost:5432/DataAnalysis")

# %%
inspector = inspect(engine)
inspector.get_table_names()
session = Session(engine)

# %%
Base = automap_base()

# %%
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
# Out:
# ['censusandlocations', 'final_table', 'analyst', 'citystate']

# %%
final = Base.classes.final_table
#census = Base.classes.censusandlocations

session = Session(engine)

# %%
import pandas as pd

# %%
finaltable = engine.execute("select * from final_table").fetchall()
finaltable
headers = ['ID', 'city', 'state_id', 'state_name', 'lat', 'lng', 'city_state', 'Ranks', 'Job_Title', 'Salary_Estimate', 'Job_Description',
          'Rating', 'Company_Name', 'jobscity', 'jobsstate', 'Industry', 'location']
finalDF = pd.DataFrame(finaltable, columns = headers)
finalDF
# Out:
#          ID        city state_id  state_name      lat       lng  \
# 0      2843     Addison       TX       Texas  32.9590  -96.8355
# 1      7016     Alachua       FL     Florida  29.7778  -82.4831
# 2       610     Alameda       CA  California  37.7670 -122.2672
# 3       557    Alhambra       CA  California  34.0840 -118.1355
# 4       436       Allen       TX       Texas  33.1088  -96.6735
# ...     ...         ...      ...         ...      ...       ...
# 1505    691  Wilmington       DE    Delaware  39.7415  -75.5413
# 1506    691  Wilmington       DE    Delaware  39.7415  -75.5413
# 1507   1469   Woodridge       IL    Illinois  41.7368  -88.0408
# 1508   1469   Woodridge       IL    Illinois  41.7368  -88.0408
# 1509  23402    Yorktown       VA    Virginia  37.2352  -76.5146
#
#           city_state  Ranks                                   Job_Title  \
# 0        Addison, TX   1377                                Data Analyst
# ...

# %%
finalDF = finalDF.drop(columns = {"jobsstate", "jobscity", "location"})
finalDF
# Out:
#          ID        city state_id  state_name      lat       lng  \
# 0      2843     Addison       TX       Texas  32.9590  -96.8355
# 1      7016     Alachua       FL     Florida  29.7778  -82.4831
# 2       610     Alameda       CA  California  37.7670 -122.2672
# 3       557    Alhambra       CA  California  34.0840 -118.1355
# 4       436       Allen       TX       Texas  33.1088  -96.6735
# ...     ...         ...      ...         ...      ...       ...
# 1505    691  Wilmington       DE    Delaware  39.7415  -75.5413
# 1506    691  Wilmington       DE    Delaware  39.7415  -75.5413
# 1507   1469   Woodridge       IL    Illinois  41.7368  -88.0408
# 1508   1469   Woodridge       IL    Illinois  41.7368  -88.0408
# 1509  23402    Yorktown       VA    Virginia  37.2352  -76.5146
#
#           city_state  Ranks                                   Job_Title  \
# 0        Addison, TX   1377                                Data Analyst
# ...

# %%
census = Base.classes.censusandlocations

session = Session(engine)

# %%
censusTable = engine.execute("select * from censusandlocations").fetchall()
censusTable
headers = ['IDcensus', 'census_city', 'state', 'Pop2010', 'Pop2011', 'Pop2012', 'Pop2013', 'Pop2014', 'Pop2015', 'Pop2016',
          'Pop2017', 'Pop2018', 'Pop2019', 'citystate', 'ID', 'city','state_id', 'state_name', 'lat', 'lng', 'city_state']
censusDF = pd.DataFrame(censusTable, columns = headers)
censusDF
# Out:
#      IDcensus  census_city       state  Pop2010  Pop2011  Pop2012  Pop2013  \
# 0         225      Abilene       Texas   117805   118762   119853   119797
# 1         125        Akron        Ohio   199081   199112   198969   198972
# 2         454      Alameda  California    73946    74692    75637    76479
# 3         502       Albany     Georgia    77420    77893    77537    76416
# 4         328       Albany    New York    97753    97956    98409    98488
# ..        ...          ...         ...      ...      ...      ...      ...
# 729       543  Yorba Linda  California    64390    65610    66282    66803
# 730       574   Youngstown        Ohio    66876    66556    66056    65470
# 731       554    Yuba City  California    65631    65364    65283    65538
# 732       722      Yucaipa  California    51474    51954    52280    52546
# 733       323         Yuma     Arizona    91328    94241    93701    92998
#
#      Pop2014  Pop2015  Pop2016  ...  Pop2018  Pop2019  \
# ...

# %%
censusDF = censusDF.drop(columns = {'ID', 'city', 'state_name', 'city_state'})
censusDF
# Out:
#      IDcensus  census_city       state  Pop2010  Pop2011  Pop2012  Pop2013  \
# 0         225      Abilene       Texas   117805   118762   119853   119797
# 1         125        Akron        Ohio   199081   199112   198969   198972
# 2         454      Alameda  California    73946    74692    75637    76479
# 3         502       Albany     Georgia    77420    77893    77537    76416
# 4         328       Albany    New York    97753    97956    98409    98488
# ..        ...          ...         ...      ...      ...      ...      ...
# 729       543  Yorba Linda  California    64390    65610    66282    66803
# 730       574   Youngstown        Ohio    66876    66556    66056    65470
# 731       554    Yuba City  California    65631    65364    65283    65538
# 732       722      Yucaipa  California    51474    51954    52280    52546
# 733       323         Yuma     Arizona    91328    94241    93701    92998
#
#      Pop2014  Pop2015  Pop2016  Pop2017  Pop2018  Pop2019  \
# ...

# %%
censusDF.to_csv("newcensus.csv")
finalDF.to_csv("final.csv")
