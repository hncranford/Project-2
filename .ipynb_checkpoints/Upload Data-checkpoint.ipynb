# %%
# SQLAlchemy
from sqlalchemy import create_engine, Column, Integer, String, Float, Date
from sqlalchemy.ext.declarative import declarative_base
import pandas as pd
import numpy as np
import os
import psycopg2
# Path to sqlite

Base = declarative_base()

# %%
cityDataDF = pd.read_csv("uscities.csv")
cityDataDF = cityDataDF.set_index('ID')
cityDataDF
# Out:
#               city   city_ascii state_id    state_name  county_fips  \
# ID
# 1         New York     New York       NY      New York        36061
# 2      Los Angeles  Los Angeles       CA    California         6037
# 3          Chicago      Chicago       IL      Illinois        17031
# 4            Miami        Miami       FL       Florida        12086
# 5           Dallas       Dallas       TX         Texas        48113
# ...            ...          ...      ...           ...          ...
# 28368    Poso Park    Poso Park       CA    California         6107
# 28369       Lotsee       Lotsee       OK      Oklahoma        40143
# 28370    The Ranch    The Ranch       MN     Minnesota        27087
# 28371      Roswell      Roswell       SD  South Dakota        46097
# 28372       Monowi       Monowi       NE      Nebraska        31015
#
#        county_name      lat       lng  population  density   source  military  \
# ID
# ...

# %%
censusDF = pd.read_csv("CensusData.csv")
#censusDf["ID"] = np.arange(oscarDf.shape[0])
censusDF = censusDF.set_index('Rank')
censusDF.head()
# Out:
#                    Geographic Area   Census  Estimates Base     2010     2011  \
# Rank
# 1          New York city, New York  8175133         8175031  8190209  8272948
# 2     Los Angeles city, California  3792621         3793139  3795512  3820876
# 3           Chicago city, Illinois  2695598         2695652  2697477  2708114
# 4              Houston city, Texas  2099451         2095517  2100280  2126032
# 5            Phoenix city, Arizona  1445632         1446691  1449038  1469796
#
#          2012     2013     2014     2015     2016     2017     2018     2019
# Rank
# 1     8346693  8396091  8433806  8463049  8469153  8437478  8390081  8336817
# 2     3851202  3881622  3909901  3938568  3963226  3975788  3977596  3979576
# 3     2719141  2725731  2727066  2724344  2716723  2711069  2701423  2693976
# 4     2161593  2199391  2241826  2286908  2309544  2316750  2318573  2320268
# 5     1499274  1526491  1555445  1583690  1612199  1633560  1654675  1680992

# %%
censusDF = censusDF.rename(columns = {'2010': 'Pop2010', '2011': 'Pop2011','2012': 'Pop2012', '2013': 'Pop2013', '2014': 'Pop2014',
                                     '2015': 'Pop2015', '2016': 'Pop2016', '2017': 'Pop2017', '2018': 'Pop2018', '2019': 'Pop2019'})
censusDF
# Out:
#                      Geographic Area   Census  Estimates Base  Pop2010  \
# Rank
# 1            New York city, New York  8175133         8175031  8190209
# 2       Los Angeles city, California  3792621         3793139  3795512
# 3             Chicago city, Illinois  2695598         2695652  2697477
# 4                Houston city, Texas  2099451         2095517  2100280
# 5              Phoenix city, Arizona  1445632         1446691  1449038
# ...                              ...      ...             ...      ...
# 784              Lakewood city, Ohio    52131           52131    52026
# 785              Troy city, New York    50129           50162    50081
# 786           Saginaw city, Michigan    51508           51469    51363
# 787     Niagara Falls city, New York    50193           50031    49996
# 788   Charleston city, West Virginia    51400           51340    51274
#
#       Pop2011  Pop2012  Pop2013  Pop2014  Pop2015  Pop2016  Pop2017  Pop2018  \
# Rank
# ...

# %%
censusDF = censusDF.rename(columns = {"Geographic Area":"Geographic_Area", "Estimates Base": "Estimates_Base"})
censusDF
# Out:
#                      Geographic_Area   Census  Estimates_Base  Pop2010  \
# Rank
# 1            New York city, New York  8175133         8175031  8190209
# 2       Los Angeles city, California  3792621         3793139  3795512
# 3             Chicago city, Illinois  2695598         2695652  2697477
# 4                Houston city, Texas  2099451         2095517  2100280
# 5              Phoenix city, Arizona  1445632         1446691  1449038
# ...                              ...      ...             ...      ...
# 784              Lakewood city, Ohio    52131           52131    52026
# 785              Troy city, New York    50129           50162    50081
# 786           Saginaw city, Michigan    51508           51469    51363
# 787     Niagara Falls city, New York    50193           50031    49996
# 788   Charleston city, West Virginia    51400           51340    51274
#
#       Pop2011  Pop2012  Pop2013  Pop2014  Pop2015  Pop2016  Pop2017  Pop2018  \
# Rank
# ...

# %%
#censusDF = censusDF.iloc[:-5]
#censusDF

# %%
#censusDF = censusDF.drop(censusDF[censusDF['Census'] == "(X)"].index, inplace = True)
censusDF = censusDF.loc[censusDF['Census'] != "(X)"]
#censusDF = censusDF[~censusDF.censusCol.str.contains("(X)")]
censusDF
# Out:
#                      Geographic_Area   Census  Estimates_Base  Pop2010  \
# Rank
# 1            New York city, New York  8175133         8175031  8190209
# 2       Los Angeles city, California  3792621         3793139  3795512
# 3             Chicago city, Illinois  2695598         2695652  2697477
# 4                Houston city, Texas  2099451         2095517  2100280
# 5              Phoenix city, Arizona  1445632         1446691  1449038
# ...                              ...      ...             ...      ...
# 784              Lakewood city, Ohio    52131           52131    52026
# 785              Troy city, New York    50129           50162    50081
# 786           Saginaw city, Michigan    51508           51469    51363
# 787     Niagara Falls city, New York    50193           50031    49996
# 788   Charleston city, West Virginia    51400           51340    51274
#
#       Pop2011  Pop2012  Pop2013  Pop2014  Pop2015  Pop2016  Pop2017  Pop2018  \
# Rank
# ...

# %%
analystJobDF = pd.read_csv("DataAnalyst.csv")
analystJobDF.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
# ...

# %%
analystJobDF = analystJobDF.rename(columns = {'Unnamed: 0':'Ranks'})
analystJobDF = analystJobDF.set_index('Ranks')
analystJobDF
# Out:
#                                                Job Title  \
# Ranks
# 0      Data Analyst, Center on Immigration and Justic...
# 1                                   Quality Data Analyst
# 2      Senior Data Analyst, Insights & Analytics Team...
# 3                                           Data Analyst
# 4                                 Reporting Data Analyst
# ...                                                  ...
# 2248   RQS - IHHA - 201900004460 -1q Data Security An...
# 2249               Senior Data Analyst (Corporate Audit)
# 2250   Technical Business Analyst (SQL, Data analytic...
# 2251                 Data Analyst 3, Customer Experience
# 2252                         Senior Quality Data Analyst
#
#                    Salary Estimate  \
# Ranks
# 0       $37K-$66K (Glassdoor est.)
# 1       $37K-$66K (Glassdoor est.)
# 2       $37K-$66K (Glassdoor est.)
# 3       $37K-$66K (Glassdoor est.)
# 4       $37K-$66K (Glassdoor est.)
# ...                            ...
# ...

# %%
analystJobDF = analystJobDF.rename(columns = {"Job Title":"Job_Title", "Salary Estimate":"Salary_Estimate", "Job Description":"Job_Description",
                                              "Type of ownership" :"Type_of_ownership","Easy Apply" :"Easy_Apply","Company Name" : "Company_Name"})
analystJobDF
# Out:
#                                                Job_Title  \
# Ranks
# 0      Data Analyst, Center on Immigration and Justic...
# 1                                   Quality Data Analyst
# 2      Senior Data Analyst, Insights & Analytics Team...
# 3                                           Data Analyst
# 4                                 Reporting Data Analyst
# ...                                                  ...
# 2248   RQS - IHHA - 201900004460 -1q Data Security An...
# 2249               Senior Data Analyst (Corporate Audit)
# 2250   Technical Business Analyst (SQL, Data analytic...
# 2251                 Data Analyst 3, Customer Experience
# 2252                         Senior Quality Data Analyst
#
#                    Salary_Estimate  \
# Ranks
# 0       $37K-$66K (Glassdoor est.)
# 1       $37K-$66K (Glassdoor est.)
# 2       $37K-$66K (Glassdoor est.)
# 3       $37K-$66K (Glassdoor est.)
# 4       $37K-$66K (Glassdoor est.)
# ...                            ...
# ...

# %%
class census(Base):
    __tablename__="citystate"
    ID = Column(Integer, primary_key = True)
    city = Column(String)
    city_ascii = Column(String)
    state_id = Column(String)
    state_name = Column(String)
    county_fips = Column(String)
    county_name = Column(String)
    lat = Column(Float)
    lng = Column(Float)
    population = Column(Float)
    density = Column(Float)
    source = Column(String)
    military = Column(String)
    incorporated= Column(String)
    timezone = Column(String)
    ranking = Column(Float)
    zips = Column(Float)
# Out:
# C:\Users\micky\Anaconda3\lib\site-packages\sqlalchemy\ext\declarative\clsregistry.py:125: SAWarning: This declarative base already contains a class with the same class name and module name as __main__.census, and will be replaced in the string-lookup table.
#   util.warn(
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-14-4a058ebf363f> in <module>
# ----> 1 class census(Base):
#       2     __tablename__="citystate"
#       3     ID = Column(Integer, primary_key = True)
#       4     city = Column(String)
#       5     city_ascii = Column(String)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\ext\declarative\api.py in __init__(cls, classname, bases, dict_)
#      73     def __init__(cls, classname, bases, dict_):
#      74         if "_decl_class_registry" not in cls.__dict__:
# ---> 75             _as_declarative(cls, classname, cls.__dict__)
# ...

# %%
class census(Base):
    __tablename__="census"
    Rank = Column(Integer, primary_key = True)
    Geographic_Area = Column(String)
    Census = Column(Float)
    Estimates_Base = Column(Float)
    Pop2010 = Column(Float)
    Pop2011 = Column(Float)
    Pop2012 = Column(Float)
    Pop2013 = Column(Float)
    Pop2014 = Column(Float)
    Pop2015 = Column(Float)
    Pop2016 = Column(Float)
    Pop2017 = Column(Float)
    Pop2018 = Column(Float)
    Pop2019 = Column(Float)

# %%
class analyst(Base):
    __tablename__="analyst"
    Ranks = Column(Integer, primary_key = True)
    Job_Title = Column(String)
    Salary_Estimate = Column(String)
    Job_Description = Column(String)
    Rating = Column(Float)
    Company_Name = Column(String)
    Location = Column(String)
    Headquarters = Column(String)
    Size = Column(String)
    Founded = Column(Float)
    Type_of_ownership = Column(String)
    Industry = Column(String)
    Sector = Column(String)
    Revenue = Column(String)
    Competitors = Column(String)
    Easy_Apply = Column(String)

# %%
database_path = "postgresql://postgres:postgres@localhost:5432/DataAnalysis"
engine = create_engine(database_path)
conn = engine.connect()

# %%
Base.metadata.create_all(engine)

# %%
from sqlalchemy.orm import Session
session = Session(bind = engine)

# %%
#censusDF.to_sql('census', con=engine, if_exists = 'append')
#analystJobDF.to_sql('analyst', con=engine, if_exists = 'append')
cityDataDF.to_sql('citystate', con=engine, if_exists = 'append')
